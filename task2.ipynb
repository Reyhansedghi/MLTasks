# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('task2train.csv')#returns a DataFrame by default
df
# Out:
#      matchId playerId          playType  bodyPart      x      y  \
# 0       m_91    p_103        جریان بازی  پای راست  13.47 -11.22
# 1       m_17     p_16        جریان بازی    پای چپ   9.48  14.22
# 2      m_111     p_88  ضربه آزاد مستقیم    پای چپ  29.43  -1.25
# 3      m_142     p_87        جریان بازی  پای راست  26.93   1.00
# 4      m_117      p_9        جریان بازی  پای راست  10.72   5.24
# ...      ...      ...               ...       ...    ...    ...
# 8920    m_57    p_115        جریان بازی        سر   6.48   3.99
# 8921    m_59     p_76        جریان بازی  پای راست  21.45  -8.73
# 8922    m_55    p_150        جریان بازی    پای چپ  11.97   3.24
# 8923    m_33    p_130        جریان بازی  پای راست   6.48  -6.98
# 8924   m_142     p_37        جریان بازی  پای راست   8.23  26.43
#
#       interveningOpponents  interveningTeammates interferenceOnShooter  \
# 0                        1                     0                 متوسط
# 1                        3                     0                 متوسط
# 2                        6                     2                    کم
# 3                        4                     1                 متوسط
# 4                        2                     0                 متوسط
# ...                    ...                   ...                   ...
# 8920                     3                     0                  زیاد
# 8921                     4                     1                 متوسط
# 8922                     3                     0                 متوسط
# 8923                     1                     0                  زیاد
# 8924                     2                     0                 متوسط
#
#       minute  second               outcome
# 0         70       9                   گُل
# 1         55       4  مهار توسط دروازه بان
# 2         86      31  مهار توسط دروازه بان
# 3         77       2    موقعیت از دست رفته
# 4         76      46                   گُل
# ...      ...     ...                   ...
# 8920      69      50    موقعیت از دست رفته
# 8921      15      53        برخورد به دفاع
# 8922      84      34    موقعیت از دست رفته
# 8923       4      39    موقعیت از دست رفته
# 8924      72      17  مهار توسط دروازه بان
#
# [8925 rows x 12 columns]

# %%
df['playerId'].nunique()
# Out:
# 160

# %%
goalsdf=df[df['outcome']=="گُل"]
goalsdf
# Out:
#      matchId playerId    playType  bodyPart      x      y  \
# 0       m_91    p_103  جریان بازی  پای راست  13.47 -11.22
# 4      m_117      p_9  جریان بازی  پای راست  10.72   5.24
# 23     m_140    p_143  جریان بازی        سر   7.23   4.99
# 30     m_110    p_104  جریان بازی    پای چپ   9.23   4.99
# 31      m_59    p_139  جریان بازی  پای راست  12.72   4.74
# ...      ...      ...         ...       ...    ...    ...
# 8840   m_119     p_77  جریان بازی  پای راست   8.23   2.74
# 8880   m_221    p_155  جریان بازی  پای راست   2.49  -1.00
# 8886   m_132     p_18  جریان بازی    پای چپ  16.71  10.23
# 8912   m_146      p_6  جریان بازی    پای چپ   7.98   7.98
# 8917   m_132    p_102  جریان بازی        سر   9.98   6.48
#
#       interveningOpponents  interveningTeammates interferenceOnShooter  \
# 0                        1                     0                 متوسط
# 4                        2                     0                 متوسط
# 23                       1                     0                    کم
# 30                       2                     0                    کم
# 31                       3                     0                 متوسط
# ...                    ...                   ...                   ...
# 8840                     2                     0                 متوسط
# 8880                     1                     0                    کم
# 8886                     3                     0                    کم
# 8912                     3                     1                 متوسط
# 8917                     2                     0                 متوسط
#
#       minute  second outcome
# 0         70       9     گُل
# 4         76      46     گُل
# 23        88      20     گُل
# 30        36      25     گُل
# 31        50       8     گُل
# ...      ...     ...     ...
# 8840      80      19     گُل
# 8880      30       6     گُل
# 8886      37      11     گُل
# 8912      18      47     گُل
# 8917      65      29     گُل
#
# [1081 rows x 12 columns]

# %%
a=goalsdf['playerId'].value_counts().idxmax()
a
# Out:
# 'p_18'

# %%
z=goalsdf['playerId'].value_counts().idxmin()
print(f"{a},{z}")
# Out:
# p_18,p_25

# %%
xx=goalsdf['x']**2
yy=goalsdf['y']**2
distance=np.floor((xx+yy)**(1/2))
goalsdf['distance']=distance
goalsdf
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7352\627479412.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   goalsdf['distance']=distance
#      matchId playerId    playType  bodyPart      x      y  \
# 0       m_91    p_103  جریان بازی  پای راست  13.47 -11.22
# 4      m_117      p_9  جریان بازی  پای راست  10.72   5.24
# 23     m_140    p_143  جریان بازی        سر   7.23   4.99
# 30     m_110    p_104  جریان بازی    پای چپ   9.23   4.99
# 31      m_59    p_139  جریان بازی  پای راست  12.72   4.74
# ...      ...      ...         ...       ...    ...    ...
# 8840   m_119     p_77  جریان بازی  پای راست   8.23   2.74
# 8880   m_221    p_155  جریان بازی  پای راست   2.49  -1.00
# 8886   m_132     p_18  جریان بازی    پای چپ  16.71  10.23
# 8912   m_146      p_6  جریان بازی    پای چپ   7.98   7.98
# 8917   m_132    p_102  جریان بازی        سر   9.98   6.48
#
#       interveningOpponents  interveningTeammates interferenceOnShooter  \
# 0                        1                     0                 متوسط
# 4                        2                     0                 متوسط
# 23                       1                     0                    کم
# 30                       2                     0                    کم
# 31                       3                     0                 متوسط
# ...                    ...                   ...                   ...
# 8840                     2                     0                 متوسط
# 8880                     1                     0                    کم
# 8886                     3                     0                    کم
# 8912                     3                     1                 متوسط
# 8917                     2                     0                 متوسط
#
#       minute  second outcome  distance
# 0         70       9     گُل      17.0
# 4         76      46     گُل      11.0
# 23        88      20     گُل       8.0
# 30        36      25     گُل      10.0
# 31        50       8     گُل      13.0
# ...      ...     ...     ...       ...
# 8840      80      19     گُل       8.0
# 8880      30       6     گُل       2.0
# 8886      37      11     گُل      19.0
# 8912      18      47     گُل      11.0
# 8917      65      29     گُل      11.0
#
# [1081 rows x 13 columns]

# %%
goalsdf['distance'].max()
# Out:
# np.float64(59.0)
